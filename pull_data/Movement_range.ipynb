# %%
from utils_peter import data_updater
import re
import json
import pandas as pd
import os

# %%
with open('../Facebook/Denmark/Movement_range/Denmark_2020_02_21.csv') as f:
    dat = json.load(f, head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8a256f8bac24> in <module>
#       1 with open('../Facebook/Denmark/Movement_range/Denmark_2020_02_21.csv') as f:
# ----> 2     dat = json.load(f, head)
#
# NameError: name 'head' is not defined

# %%
path = '../Facebook/Denmark/Movement_range/'
files = os.listdir(path)

# %%
dat = pd.read_csv(path+files[10])
dat
# Out:
#             ds crisis_name  polygon_id          polygon_name age_bracket  \
# 0   2020-03-02    DK_NUTS3         553              Bornholm     Overall
# 1   2020-03-02    DK_NUTS3         552          Nordsjælland     Overall
# 2   2020-03-02    DK_NUTS3         560           Nordjylland     Overall
# 3   2020-03-02    DK_NUTS3         554           Østsjælland     Overall
# 4   2020-03-02    DK_NUTS3         558           Vestjylland     Overall
# 5   2020-03-02    DK_NUTS3         556                   Fyn     Overall
# 6   2020-03-02    DK_NUTS3         550        Byen København     Overall
# 7   2020-03-02    DK_NUTS3         557            Sydjylland     Overall
# 8   2020-03-02    DK_NUTS3         555  Vest- og Sydsjælland     Overall
# 9   2020-03-02    DK_NUTS3         551      Københavns omegn     Overall
# 10  2020-03-02    DK_NUTS3         559            Østjylland     Overall
#
#      gender  baseline_name baseline_type  \
# 0   Overall  full_february   DAY_OF_WEEK
# ...

# %%
path = '../Facebook/Sweden/population_tile/'
files = os.listdir(path)
pd.read_csv(path+files[0]).columns

# %%
# Out:
# Index(['lat', 'lon', 'quadkey', 'country', 'date_time', 'n_baseline',
#        'n_crisis', 'n_difference', 'density_baseline', 'density_crisis',
#        'percent_change', 'clipped_z_score', 'ds'],
#       dtype='object')

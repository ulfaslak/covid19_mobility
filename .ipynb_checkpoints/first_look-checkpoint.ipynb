# %%
import os
import pandas as pd
from PIL import Image

# %% [markdown]
# # movement_between_tiles

# %%
path = 'movement_between_tiles'
files = os.listdir(path)
pd.read_csv(path + "/" + files[0])
# Out:
#      Difference  Baseline: People Moving  Crisis: People Moving  \
# 0         -44.8                     66.8                     22
# 1          -4.4                     16.4                     12
# 2          -7.2                     22.2                     15
# 3           0.8                     11.2                     12
# 4           3.8                     15.2                     19
# 5           5.8                     11.2                     17
# 6          -8.4                     24.4                     16
# 7          -5.0                     21.0                     16
# 8         -10.2                     20.2                     10
# 9          -1.4                     26.4                     25
# 10         -9.2                     19.2                     10
# 11          0.2                     10.8                     11
# 12          3.4                     12.6                     16
# 13         -1.4                     19.4                     18
# ...

# %%
path = 'facebook_population_tile_level'
files = os.listdir(path)
im = Image.open(path + "/" + files[0])
im.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-ba86533ccc37> in <module>
#       1 path = 'facebook_population_tile_level'
#       2 files = os.listdir(path)
# ----> 3 im = Image.open(path + "/" + files[0])
#       4 im.show()
#
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#    2816     for message in accept_warnings:
#    2817         warnings.warn(message)
# -> 2818     raise IOError("cannot identify image file %r" % (filename if filename else fp))
#    2819
#    2820
#
# OSError: cannot identify image file 'facebook_population_tile_level/20200328_1600.tif'

# %%
ls
# Out:
# Icon?
# facebook_population_administrative_regions/
# facebook_population_tile_level/
# firstlook.ipynb
# movement_between_administrative_regions/
# movement_between_tiles/
